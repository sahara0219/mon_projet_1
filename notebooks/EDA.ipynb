# %%
import pandas as pd

import plotly.express as px
import plotly.graph_objects as go 

import streamlit as st 
import streamlit.components.v1 as components

# %%
car_data = pd.read_csv('vehicles_us (1).csv',sep=',')

# %%
car_data.to_csv("vehicles_us (1).csv", index=False) # Guardar el DataFrame en un archivo CSV

car_data.info() #informacion del dataframe 

car_data = car_data.drop_duplicates() #eliminacion de los duplicados

car_data = car_data.dropna() #eliminacion de los valores nulos 

car_data.columns = car_data.columns.str.lower().str.replace(" ", "_") #cambio de nombre de las columnas

car_data.head() #visualizacion de los primeros 5 datos del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#     price  model_year                     model  condition  cylinders fuel  \
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# 14  12990      2009.0                 gmc yukon  excellent        8.0  gas
# 16  14990      2010.0                  ram 1500  excellent        8.0  gas
#
#     odometer transmission    type paint_color  is_4wd date_posted  days_listed
# 5    57954.0    automatic   sedan       black     1.0  2018-06-20           15
# 7   109473.0    automatic     SUV       black     1.0  2019-01-07           68
# 10  128413.0    automatic  pickup       black     1.0  2018-09-17           38
# 14  132285.0    automatic     SUV       black     1.0  2019-01-31           24
# 16  130725.0    automatic  pickup         red     1.0  2018-12-30           13

# %%
st.title("Analisis de Vehiculos en Estados Unidos (2019-2020)") #titulo de la aplicacion

st.sidebar.header("Opciones de visualizacion") #opcines de visualizacion
st.write("Eeste es un analisis de los vehiculos en Estados Unidos durante los años 2019 y 2020, donde se analiza el tipo de combustible, el tipo de vehiculo, la marca y el modelo de los vehiculos.") # descripcion de la aplicascion 

st.subheader("Datos de los vehiculos") #subtitulos de la aplicacion

st.dataframe() #visualizacion de los datos en un dataframe 
st.write("Tolal de vehiculos:", len(car_data)) #total de vehiculos 
st.write("Total de marcas:", car_data['model'].nunique()) # total de marcas 
st.write("Total de modelos:",car_data ['model_year'].nunique()) #total de modelos 
st.write("Total de tipos de combustible:", car_data['fuel'].nunique()) #total de tipos de combustible
st.write("tipos de trasmision:", car_data['transmission'].nunique()) #total de tipos de trasmision
# Out:
# 2025-07-24 19:22:54.729 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.817
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/envs/myenv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-07-24 19:22:54.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:54.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
fig = go.Figure(data=[go.Histogram(x=car_data['odometer'])]) # Crear un histograma utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de histograma
fig.update_layout(title_text='Distribución del Odómetro') # Opcional: Puedes añadir un título al gráfico si lo deseas
fig.show()# Mostrar el gráfico Plotly

fig = go.Figure(data=[go.Scatter(x=car_data['odometer'], y=car_data['price'], mode='markers')]) # Crear un scatter plot utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de scatter
fig.update_layout(title_text='Relación entre Odómetro y Precio') # Opcional: Puedes añadir un título al gráfico si lo deseas
fig.show() # Mostrar el gráfico Plotly

# %%
if st.button('Construir histograma',key ='1'):
   st.write('Creación de un histograma para el conjunto de datos de anuncios de venta de coches')
   fig = go.Figure(data=[go.Histogram(x=car_data['odometer'])]) # Crear un histograma utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de histograma
   fig.update_layout(title_text='Distribución del Odómetro') # Opcional: Puedes añadir un título al gráfico si lo deseas
   st.plotly_chart(fig, use_container_width=True) # Mostrar el gráfico Plotly interactivo en la aplicación Streamlit
    # 'use_container_width=True' ajusta el ancho del gráfico al contenedor
   st.plotly_chart(fig, use_container_width=True)
   fig.show()# Mostrar el gráfico Plotly

build_dis = st.checkbox('Construir grafico de dispersion', value=False)# checkbox para controlar la construccion del grafico de dispersion

if build_dis:
   st.write('creacion de un grafico de dispersion para el conjunto de datos de anuncios de ventas de cohces')
   st.write('Este grafico muestra la relacion entre el odometro y el precio de los vehiculos')

   fig_2= go.Figure(data=[go.Scatter(x=car_data['odometer'], y=car_data['price'], mode='markers')]) # Crear un scatter plot utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de scatter
   fig_2.update_layout(title_text='Relación entre Odómetro y Precio') # Opcional: Puedes añadir un título al gráfico si lo deseas
   fig_2.show() # Mostrar el gráfico Plotly
# Out:
# 2025-07-24 19:22:55.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:22:55.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
