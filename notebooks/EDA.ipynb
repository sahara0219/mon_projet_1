# %%
import pandas as pd

import plotly.express as px
import plotly.graph_objects as go 

import streamlit as st 
import streamlit.components.v1 as components

# %%
car_data = pd.read_csv('../vehicles_us (1).csv',sep=',')

# %%
car_data.to_csv("../vehicles_us (1).csv", index=False) # Guardar el DataFrame en un archivo CSV

car_data.info() #informacion del dataframe 

car_data = car_data.drop_duplicates() #eliminacion de los duplicados

car_data = car_data.dropna() #eliminacion de los valores nulos 

car_data.columns = car_data.columns.str.lower().str.replace(" ", "_") #cambio de nombre de las columnas

car_data.head() #visualizacion de los primeros 5 datos del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#     price  model_year                     model  condition  cylinders fuel  \
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# 14  12990      2009.0                 gmc yukon  excellent        8.0  gas
# 16  14990      2010.0                  ram 1500  excellent        8.0  gas
#
#     odometer transmission    type paint_color  is_4wd date_posted  days_listed
# 5    57954.0    automatic   sedan       black     1.0  2018-06-20           15
# 7   109473.0    automatic     SUV       black     1.0  2019-01-07           68
# 10  128413.0    automatic  pickup       black     1.0  2018-09-17           38
# 14  132285.0    automatic     SUV       black     1.0  2019-01-31           24
# 16  130725.0    automatic  pickup         red     1.0  2018-12-30           13

# %%
st.title("Analisis de Vehiculos en Estados Unidos (2019-2020)") #titulo de la aplicacion

st.sidebar.header("Opciones de visualizacion") #opcines de visualizacion
st.write("Eeste es un analisis de los vehiculos en Estados Unidos durante los años 2019 y 2020, donde se analiza el tipo de combustible, el tipo de vehiculo, la marca y el modelo de los vehiculos.") # descripcion de la aplicascion 

st.subheader("Datos de los vehiculos") #subtitulos de la aplicacion

st.dataframe() #visualizacion de los datos en un dataframe 
st.write("Tolal de vehiculos:", len(car_data)) #total de vehiculos 
st.write("Total de marcas:", car_data['model'].nunique()) # total de marcas 
st.write("Total de modelos:",car_data ['model_year'].nunique()) #total de modelos 
st.write("Total de tipos de combustible:", car_data['fuel'].nunique()) #total de tipos de combustible
st.write("tipos de trasmision:", car_data['transmission'].nunique()) #total de tipos de trasmision
# Out:
# 2025-07-24 19:58:57.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:58:57.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
fig = go.Figure(data=[go.Histogram(x=car_data['odometer'])]) # Crear un histograma utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de histograma
fig.update_layout(title_text='Distribución del Odómetro') # Opcional: Puedes añadir un título al gráfico si lo deseas
fig.show()# Mostrar el gráfico Plotly

# %%
fig = go.Figure(data=[go.Scatter(x=car_data['odometer'], y=car_data['price'], mode='markers')]) # Crear un scatter plot utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de scatter
fig.update_layout(title_text='Relación entre Odómetro y Precio') # Opcional: Puedes añadir un título al gráfico si lo deseas
fig.show() # Mostrar el gráfico Plotly

fig = go.scatter ( car_data , x = "ancho_del_sépalo" , y = "longitud_del_sépalo" , color = "especie" , tamaño = 'longitud_del_pétalo' , hover_data = [ 'ancho_del_pétalo' ]) fig . show ()
# Out:
#   Cell In[35], line 6
#     fig = go.scatter ( car_data , x = "ancho_del_sépalo" , y = "longitud_del_sépalo" , color = "especie" , tamaño = 'longitud_del_pétalo' , hover_data = [ 'ancho_del_pétalo' ]) fig . show ()
#                                                                                                                                                                                  ^
# SyntaxError: invalid syntax

# %%
if st.button('Construir histograma',key ='1'):
   st.write('Creación de un histograma para el conjunto de datos de anuncios de venta de coches')
   fig = go.Figure(data=[go.Histogram(x=car_data['odometer'])]) # Crear un histograma utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de histograma
   fig.update_layout(title_text='Distribución del Odómetro') # Opcional: Puedes añadir un título al gráfico si lo deseas
   st.plotly_chart(fig, use_container_width=True) # Mostrar el gráfico Plotly interactivo en la aplicación Streamlit
    # 'use_container_width=True' ajusta el ancho del gráfico al contenedor
   st.plotly_chart(fig, use_container_width=True)
   fig.show()# Mostrar el gráfico Plotly

build_dis = st.checkbox('Construir grafico de dispersion', value=False)# checkbox para controlar la construccion del grafico de dispersion

if build_dis:
   st.write('creacion de un grafico de dispersion para el conjunto de datos de anuncios de ventas de cohces')
   st.write('Este grafico muestra la relacion entre el odometro y el precio de los vehiculos')

   fig_2= go.Figure(data=[go.Scatter(x=car_data['odometer'], y=car_data['price'], mode='markers')]) # Crear un scatter plot utilizando plotly.graph_objects
# Se crea una figura vacía y luego se añade un rastro de scatter
   fig_2.update_layout(title_text='Relación entre Odómetro y Precio') # Opcional: Puedes añadir un título al gráfico si lo deseas
   fig_2.show() # Mostrar el gráfico Plotly
# Out:
# 2025-07-24 19:29:54.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-24 19:29:54.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
