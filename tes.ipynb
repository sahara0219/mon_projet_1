# %%
import pandas as pd 
import streamlit as st 
import plotly_express as px 
import nbformat as nbf

# %% [markdown]
# # Como puedo crear un boton para crear diferentes histogramas con los datos mas relevantes de los vehiculos para una mejor visualizacion de los resultados

# %%
vehiculos = pd.read_csv("vehicles_us (1).csv",sep=',') #lectura del archivo csv

vehiculos.to_csv("vehiculos.csv", index=False) # Guardar el DataFrame en un archivo CSV

vehiculos.info() #informacion del dataframe 

vehiculos = vehiculos.drop_duplicates() #eliminacion de los duplicados

vehiculos = vehiculos.dropna() #eliminacion de los valores nulos 

vehiculos.columns = vehiculos.columns.str.lower().str.replace(" ", "_") #cambio de nombre de las columnas

vehiculos.head() #visualizacion de los primeros 5 datos del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#     price  model_year                     model  condition  cylinders fuel  \
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# 14  12990      2009.0                 gmc yukon  excellent        8.0  gas
# 16  14990      2010.0                  ram 1500  excellent        8.0  gas
#
#     odometer transmission    type paint_color  is_4wd date_posted  days_listed
# 5    57954.0    automatic   sedan       black     1.0  2018-06-20           15
# 7   109473.0    automatic     SUV       black     1.0  2019-01-07           68
# 10  128413.0    automatic  pickup       black     1.0  2018-09-17           38
# 14  132285.0    automatic     SUV       black     1.0  2019-01-31           24
# 16  130725.0    automatic  pickup         red     1.0  2018-12-30           13

# %%
st.title("Analisis de Vehiculos en Estados Unidos (2019-2020)") #titulo de la aplicacion

st.sidebar.header("Opciones de visualizacion") #opcines de visualizacion
st.write("Eeste es un analisis de los vehiculos en Estados Unidos durante los años 2019 y 2020, donde se analiza el tipo de combustible, el tipo de vehiculo, la marca y el modelo de los vehiculos.") # descripcion de la aplicascion 

st.subheader("Datos de los vehiculos") #subtitulos de la aplicacion

st.dataframe(vehiculos) #visualizacion de los datos en un dataframe 
st.write("Tolal de vehiculos:", len(vehiculos)) #total de vehiculos 
st.write("Total de marcas:", vehiculos['model'].nunique()) # total de marcas 
st.write("Total de modelos:", vehiculos['model_year'].nunique()) #total de modelos 
st.write("Total de tipos de combustible:", vehiculos['fuel'].nunique()) #total de tipos de combustible
st.write("tipos de trasmision:", vehiculos['transmission'].nunique()) #total de tipos de trasmision
# Out:
# 2025-07-22 20:43:18.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-22 20:43:18.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# graficas para el analiciz

# %%
fig = px.bar(vehiculos, x=model)
fig = px.bar(vehiculos, x='model', y='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fig = px.bar(vehiculos, x=model)
#       2 fig = px.bar(vehiculos, x='model', y='')
#
# NameError: name 'model' is not defined

# %%
vehiculos.to_csv('vehiculos_limpios.csv',index=False) # Guardar el DataFrame limpio en un archive csv
